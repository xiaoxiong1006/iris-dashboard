# %%
# %env FLASK_DEBUG=1
# !flask run --port=8556 --host=0.0.0.0
# Out:
# env: FLASK_DEBUG=1
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:8556
#  * Running on http://192.168.1.100:8556
# Press CTRL+C to quit
#  * Restarting with stat
#  * Debugger is active!
#  * Debugger PIN: 791-756-564
# 127.0.0.1 - - [11/Dec/2023 17:03:57] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Dec/2023 17:03:57] "GET /static/js/echarts.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Dec/2023 17:03:57] "GET /iris_species_counts HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Dec/2023 17:04:41] "GET /static/js/echarts.js.map HTTP/1.1" 404 -
# 127.0.0.1 - - [11/Dec/2023 17:05:21] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Dec/2023 17:05:21] "GET /static/js/echarts.js HTTP/1.1" 200 -
# 127.0.0.1 - - [11/Dec/2023 17:05:21] "GET /static/js/echarts.js.map HTTP/1.1" 404 -
# ...

# %% [markdown]
# ![image.png](attachment:705255f4-8dfc-4e82-91a2-7ee5fc9db3ed.png)

# %% [markdown]
# #!pip install flask -i https://pypi.tuna.tsinghua.edu.cn/simple
